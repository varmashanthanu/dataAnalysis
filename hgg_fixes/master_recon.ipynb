# %% [markdown]
# # Tony's Recon Process
# This script will do a full audit on all of Tony's receivers. The following aspects will be checked:
# 1. did all the files in the `raw_files` archive dir enter the `processed` dir?
# 2. did all the receivers from the files in the `raw_files` make it to the export location in the DB?
# 3. are any of the dangling images matching with ANY \[unfiltered] receiver in the export location?
# 4. are any of the dangling images matching with any receiver in the raw files?
# This script will not auto resolve the issues, this will provide a status report

# %% [markdown]
# ### Setup

# %%
from datetime import datetime
import json
import os
import re
import warnings
from pandas.errors import SettingWithCopyWarning

from stat import S_ISDIR

import pandas as pd
from IPython.core.display import HTML

from db import engine
from sftp_connection import get_sftp


FROM_DATE = '2024-01-01'
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %%
# Load SBT Vendors Table
sbt_vendors = pd.read_csv('../sbt_vendors.csv')

# %% [markdown]
# ## Audit received and processed files
# ### Helpers to get files from SFTP, and others

# %%
# Helper to get list of valid files from sftp location
def get_sftp_files(full_directory_path: str, from_date: str = None) -> list:
    """
    Helper to get a list of files in a requested directory, optionally from a date
    Args:
        full_directory_path: full directory path for the files
        from_date: (optional) the oldest date (inclusive) from when to filter the files for, format: YYY-MM-DD

    Returns:
        a list of file names in the directory
    """
    from_date_timestamp = datetime.strptime(from_date, '%Y-%m-%d').timestamp() if from_date else None
    with get_sftp() as sftp:
        sftp.chdir(full_directory_path)
        files_list = [file for file in sftp.listdir_attr() if not S_ISDIR(file.st_mode)]

        if from_date_timestamp:
            files_list = [file for file in files_list if file.st_mtime >= from_date_timestamp]
        else:
            files_list = [file for file in files_list]

    return files_list

# Helper to read the files from sftp location
def read_sftp_files(full_directory_path: str, filenames_list: list) -> dict:
    """
    Helper to get the contents of the requested files from a requested directory
    Args:
        full_directory_path: full directory path for the files
        filenames_list: list of str file names to be read

    Returns:
        a dict map of filenames to file contents
    """
    filename_to_receivers_map = {}
    with get_sftp() as sftp:
        sftp.chdir(full_directory_path)
        for i, filename in enumerate(filenames_list):
            print(f'Reading file {i+1} of {len(filenames_list)}')
            with sftp.open(filename) as fp:
                filename_to_receivers_map[filename] = json.loads(fp.read())

    return filename_to_receivers_map

# %%
# Helper to normalise and count number of files
def get_dates_to_files_map(files: list) -> pd.DataFrame:
    """
    A Helper to get the count of files by date
    Args:
        files: list of files

    Returns:
        a date distribution of file count
    """
    filename_to_date_map = {'filename': [], 'date': []}
    for file in files:
        cleaned_filename = get_original_filename(file.filename)
        if cleaned_filename not in filename_to_date_map['filename']:
            filename_to_date_map['filename'].append(cleaned_filename)
            date = datetime.fromtimestamp(file.st_mtime).strftime('%Y-%m-%d')
            filename_to_date_map['date'].append(date)

    return pd.DataFrame(filename_to_date_map)

# %%
# clean the file names to get the original file name
def get_original_filename(filename: str) -> str:
    """
    Helper method to retrieve the original name of the uploaded file
        Uploaded files are renamed when moved to the raw files and processed files folders. The renaming for a file e.g. "receiver_uploads.json" is:
            raw_files/receiver_uploads__RANDINT.json
            processed/receiver_uploads__BATCHINT__INGSTID.json
    Args:
        filename: the name of the file post-processing

    Returns:
        str filename of the original file
    """
    name, ext = filename.split('.')
    original_name = name.split('__')[0]

    return f"{original_name}.{ext}"

# %%
# Set up FTP directory and get files list
root_directory = 'Tonys_Stores_Inbound'
from_date = FROM_DATE

# Get files in the raw files directory
raw_files_folder = 'raw_files'
raw_files_list = get_sftp_files(os.path.join(root_directory, raw_files_folder), from_date)

# Get files in processed folder
processed_folder = 'processed'
processed_files_list = get_sftp_files(os.path.join(root_directory, processed_folder), from_date)

# %%
# compare number of files from each folder for the given date range
raw_files_data = get_dates_to_files_map(raw_files_list)
processed_files_data = get_dates_to_files_map(processed_files_list)

# %%
# Do some cleanup on the raw files and the processed files to compare the counts
raw_files_count = raw_files_data.groupby(['date']).count().reset_index()
processed_files_count = processed_files_data.groupby(['date']).count().reset_index()
raw_to_processed_files_comparison_df = raw_files_count.merge(processed_files_count, on='date', suffixes=('_raw', '_processed'))
raw_to_processed_files_comparison_df['mismatch'] = raw_to_processed_files_comparison_df.apply(lambda x: x.filename_raw - x.filename_processed, axis=1)

# %%
# Track the files that may have not ingested
raw_files_names_list = raw_files_data.filename.unique().tolist()
processed_files_names_list = processed_files_data.filename.unique().tolist()
missing_in_processed_list = [filename for filename in raw_files_names_list if filename not in processed_files_names_list]

# %% [markdown]
# ## Audit received and processed receivers

# %%
# Helpers to get exact match keys and fuzzy match keys
def get_match_key(row: dict, exact_match: bool = True) -> str:
    """
    Helper to get match key for exact matches
    Args:
        row:
        exact_match:

    Returns:
        tuple with the match key
    """
    pattern = re.compile("[\W_]+") if exact_match else re.compile("[^\d]")
    return f"{row['location_id']}__{row['vendor_id']}__{pattern.sub('', row['invoice_number'])}"

# %%
def receivers_json_to_df(filename_to_contents_dict: dict) -> pd.DataFrame:
    """
    Helper to convert dict of receivers to
    Args:
        filename_to_contents_dict:

    Returns:

    """
    receivers_map = {'invoice_number': [], 'location_id': [], 'vendor_id': [], 'total_amount': [], 'date': [], 'filename': []}
    for i, (filename, receivers_json_list) in enumerate(filename_to_contents_dict.items()):
        print(f'Reading file {i+1} of {len(filename_to_contents_dict)}')
        for j, receiver in enumerate(receivers_json_list):
            print(f'Parsing receiver {j+1} of {len(receivers_json_list)}')
            receivers_map['invoice_number'].append(receiver.get('InvoiceNumber'))
            receivers_map['location_id'].append(receiver.get('Location'))
            receivers_map['vendor_id'].append(receiver.get('Vendor'))
            receivers_map['total_amount'].append(receiver.get('Total'))
            receivers_map['date'].append(receiver.get('InvoiceDate'))
            receivers_map['filename'].append(filename)

    receivers_df = pd.DataFrame(receivers_map)
    receivers_df.drop_duplicates(inplace=True, keep='last')
    receivers_df['date'] = pd.to_datetime(receivers_df['date'])

    return receivers_df

# %%
# Get all receivers from the raw files
raw_files_to_receivers_json = read_sftp_files(os.path.join(root_directory, raw_files_folder), filenames_list=[file.filename for file in raw_files_list])
raw_receivers_df = receivers_json_to_df(raw_files_to_receivers_json)
raw_receivers_df.drop_duplicates(subset=['invoice_number', 'date', 'total_amount', 'vendor_id', 'location_id'], keep='first', inplace=True)
# Get all receivers from the processed files
processed_files_to_receivers_json = read_sftp_files(os.path.join(root_directory, processed_folder), filenames_list=[file.filename for file in processed_files_list])
processed_receivers_df = receivers_json_to_df(processed_files_to_receivers_json)
processed_receivers_df.drop_duplicates(subset=['invoice_number', 'date', 'total_amount', 'vendor_id', 'location_id'], keep='first', inplace=True)
# Out:
# Reading file 1 of 636
# Reading file 2 of 636
# Reading file 3 of 636
# Reading file 4 of 636
# Reading file 5 of 636
# Reading file 6 of 636
# Reading file 7 of 636
# Reading file 8 of 636
# Reading file 9 of 636
# Reading file 10 of 636
# Reading file 11 of 636
# Reading file 12 of 636
# Reading file 13 of 636
# Reading file 14 of 636
# Reading file 15 of 636
# Reading file 16 of 636
# Reading file 17 of 636
# Reading file 18 of 636
# Reading file 19 of 636
# Reading file 20 of 636
# Reading file 21 of 636
# Reading file 22 of 636
# Reading file 23 of 636
# Reading file 24 of 636
# Reading file 25 of 636
# Reading file 26 of 636
# Reading file 27 of 636
# Reading file 28 of 636
# Reading file 29 of 636
# Reading file 30 of 636
# Reading file 31 of 636
# Reading file 32 of 636
# Reading file 33 of 636
# Reading file 34 of 636
# Reading file 35 of 636
# Reading file 36 of 636
# Reading file 37 of 636
# Reading file 38 of 636
# Reading file 39 of 636
# Reading file 40 of 636
# Reading file 41 of 636
# Reading file 42 of 636
# Reading file 43 of 636
# Reading file 44 of 636
# Reading file 45 of 636
# Reading file 46 of 636
# Reading file 47 of 636
# Reading file 48 of 636
# Reading file 49 of 636
# Reading file 50 of 636
# Reading file 51 of 636
# Reading file 52 of 636
# Reading file 53 of 636
# Reading file 54 of 636
# Reading file 55 of 636
# Reading file 56 of 636
# Reading file 57 of 636
# Reading file 58 of 636
# Reading file 59 of 636
# Reading file 60 of 636
# Reading file 61 of 636
# Reading file 62 of 636
# Reading file 63 of 636
# Reading file 64 of 636
# Reading file 65 of 636
# Reading file 66 of 636
# Reading file 67 of 636
# Reading file 68 of 636
# Reading file 69 of 636
# Reading file 70 of 636
# Reading file 71 of 636
# Reading file 72 of 636
# Reading file 73 of 636
# Reading file 74 of 636
# Reading file 75 of 636
# Reading file 76 of 636
# Reading file 77 of 636
# Reading file 78 of 636
# Reading file 79 of 636
# Reading file 80 of 636
# Reading file 81 of 636
# Reading file 82 of 636
# Reading file 83 of 636
# Reading file 84 of 636
# Reading file 85 of 636
# Reading file 86 of 636
# Reading file 87 of 636
# Reading file 88 of 636
# Reading file 89 of 636
# Reading file 90 of 636
# Reading file 91 of 636
# Reading file 92 of 636
# Reading file 93 of 636
# Reading file 94 of 636
# Reading file 95 of 636
# Reading file 96 of 636
# Reading file 97 of 636
# Reading file 98 of 636
# Reading file 99 of 636
# Reading file 100 of 636
# Reading file 101 of 636
# Reading file 102 of 636
# Reading file 103 of 636
# Reading file 104 of 636
# Reading file 105 of 636
# Reading file 106 of 636
# Reading file 107 of 636
# Reading file 108 of 636
# Reading file 109 of 636
# Reading file 110 of 636
# Reading file 111 of 636
# Reading file 112 of 636
# Reading file 113 of 636
# Reading file 114 of 636
# Reading file 115 of 636
# Reading file 116 of 636
# Reading file 117 of 636
# Reading file 118 of 636
# Reading file 119 of 636
# Reading file 120 of 636
# Reading file 121 of 636
# Reading file 122 of 636
# Reading file 123 of 636
# Reading file 124 of 636
# Reading file 125 of 636
# Reading file 126 of 636
# Reading file 127 of 636
# Reading file 128 of 636
# Reading file 129 of 636
# Reading file 130 of 636
# Reading file 131 of 636
# Reading file 132 of 636
# Reading file 133 of 636
# Reading file 134 of 636
# Reading file 135 of 636
# Reading file 136 of 636
# Reading file 137 of 636
# Reading file 138 of 636
# Reading file 139 of 636
# Reading file 140 of 636
# Reading file 141 of 636
# Reading file 142 of 636
# Reading file 143 of 636
# Reading file 144 of 636
# Reading file 145 of 636
# Reading file 146 of 636
# Reading file 147 of 636
# Reading file 148 of 636
# Reading file 149 of 636
# Reading file 150 of 636
# Reading file 151 of 636
# Reading file 152 of 636
# Reading file 153 of 636
# Reading file 154 of 636
# Reading file 155 of 636
# Reading file 156 of 636
# Reading file 157 of 636
# Reading file 158 of 636
# Reading file 159 of 636
# Reading file 160 of 636
# Reading file 161 of 636
# Reading file 162 of 636
# Reading file 163 of 636
# Reading file 164 of 636
# Reading file 165 of 636
# Reading file 166 of 636
# Reading file 167 of 636
# Reading file 168 of 636
# Reading file 169 of 636
# Reading file 170 of 636
# Reading file 171 of 636
# Reading file 172 of 636
# Reading file 173 of 636
# Reading file 174 of 636
# Reading file 175 of 636
# Reading file 176 of 636
# Reading file 177 of 636
# Reading file 178 of 636
# Reading file 179 of 636
# Reading file 180 of 636
# Reading file 181 of 636
# Reading file 182 of 636
# Reading file 183 of 636
# Reading file 184 of 636
# Reading file 185 of 636
# Reading file 186 of 636
# Reading file 187 of 636
# Reading file 188 of 636
# Reading file 189 of 636
# Reading file 190 of 636
# Reading file 191 of 636
# Reading file 192 of 636
# Reading file 193 of 636
# Reading file 194 of 636
# Reading file 195 of 636
# Reading file 196 of 636
# Reading file 197 of 636
# Reading file 198 of 636
# Reading file 199 of 636
# Reading file 200 of 636
# Reading file 201 of 636
# Reading file 202 of 636
# Reading file 203 of 636
# Reading file 204 of 636
# Reading file 205 of 636
# Reading file 206 of 636
# Reading file 207 of 636
# Reading file 208 of 636
# Reading file 209 of 636
# Reading file 210 of 636
# Reading file 211 of 636
# Reading file 212 of 636
# Reading file 213 of 636
# Reading file 214 of 636
# Reading file 215 of 636
# Reading file 216 of 636
# Reading file 217 of 636
# Reading file 218 of 636
# Reading file 219 of 636
# Reading file 220 of 636
# Reading file 221 of 636
# Reading file 222 of 636
# Reading file 223 of 636
# Reading file 224 of 636
# Reading file 225 of 636
# Reading file 226 of 636
# Reading file 227 of 636
# Reading file 228 of 636
# Reading file 229 of 636
# Reading file 230 of 636
# Reading file 231 of 636
# Reading file 232 of 636
# Reading file 233 of 636
# Reading file 234 of 636
# Reading file 235 of 636
# Reading file 236 of 636
# Reading file 237 of 636
# Reading file 238 of 636
# Reading file 239 of 636
# Reading file 240 of 636
# Reading file 241 of 636
# Reading file 242 of 636
# Reading file 243 of 636
# Reading file 244 of 636
# Reading file 245 of 636
# Reading file 246 of 636
# Reading file 247 of 636
# Reading file 248 of 636
# Reading file 249 of 636
# Reading file 250 of 636
# Reading file 251 of 636
# Reading file 252 of 636
# Reading file 253 of 636
# Reading file 254 of 636
# Reading file 255 of 636
# Reading file 256 of 636
# Reading file 257 of 636
# Reading file 258 of 636
# Reading file 259 of 636
# Reading file 260 of 636
# Reading file 261 of 636
# Reading file 262 of 636
# Reading file 263 of 636
# Reading file 264 of 636
# Reading file 265 of 636
# Reading file 266 of 636
# Reading file 267 of 636
# Reading file 268 of 636
# Reading file 269 of 636
# Reading file 270 of 636
# Reading file 271 of 636
# Reading file 272 of 636
# Reading file 273 of 636
# Reading file 274 of 636
# Reading file 275 of 636
# Reading file 276 of 636
# Reading file 277 of 636
# Reading file 278 of 636
# Reading file 279 of 636
# Reading file 280 of 636
# Reading file 281 of 636
# Reading file 282 of 636
# Reading file 283 of 636
# Reading file 284 of 636
# Reading file 285 of 636
# Reading file 286 of 636
# Reading file 287 of 636
# Reading file 288 of 636
# Reading file 289 of 636
# Reading file 290 of 636
# Reading file 291 of 636
# Reading file 292 of 636
# Reading file 293 of 636
# Reading file 294 of 636
# Reading file 295 of 636
# Reading file 296 of 636
# Reading file 297 of 636
# Reading file 298 of 636
# Reading file 299 of 636
# Reading file 300 of 636
# Reading file 301 of 636
# Reading file 302 of 636
# Reading file 303 of 636
# Reading file 304 of 636
# Reading file 305 of 636
# Reading file 306 of 636
# Reading file 307 of 636
# Reading file 308 of 636
# Reading file 309 of 636
# Reading file 310 of 636
# Reading file 311 of 636
# Reading file 312 of 636
# Reading file 313 of 636
# Reading file 314 of 636
# Reading file 315 of 636
# Reading file 316 of 636
# Reading file 317 of 636
# Reading file 318 of 636
# Reading file 319 of 636
# Reading file 320 of 636
# Reading file 321 of 636
# Reading file 322 of 636
# Reading file 323 of 636
# Reading file 324 of 636
# Reading file 325 of 636
# Reading file 326 of 636
# Reading file 327 of 636
# Reading file 328 of 636
# Reading file 329 of 636
# Reading file 330 of 636
# Reading file 331 of 636
# Reading file 332 of 636
# Reading file 333 of 636
# Reading file 334 of 636
# Reading file 335 of 636
# Reading file 336 of 636
# Reading file 337 of 636
# Reading file 338 of 636
# Reading file 339 of 636
# Reading file 340 of 636
# Reading file 341 of 636
# Reading file 342 of 636
# Reading file 343 of 636
# Reading file 344 of 636
# Reading file 345 of 636
# Reading file 346 of 636
# Reading file 347 of 636
# Reading file 348 of 636
# Reading file 349 of 636
# Reading file 350 of 636
# Reading file 351 of 636
# Reading file 352 of 636
# Reading file 353 of 636
# Reading file 354 of 636
# Reading file 355 of 636
# Reading file 356 of 636
# Reading file 357 of 636
# Reading file 358 of 636
# Reading file 359 of 636
# Reading file 360 of 636
# Reading file 361 of 636
# Reading file 362 of 636
# Reading file 363 of 636
# Reading file 364 of 636
# Reading file 365 of 636
# Reading file 366 of 636
# Reading file 367 of 636
# Reading file 368 of 636
# Reading file 369 of 636
# Reading file 370 of 636
# Reading file 371 of 636
# Reading file 372 of 636
# Reading file 373 of 636
# Reading file 374 of 636
# Reading file 375 of 636
# Reading file 376 of 636
# Reading file 377 of 636
# Reading file 378 of 636
# Reading file 379 of 636
# Reading file 380 of 636
# Reading file 381 of 636
# Reading file 382 of 636
# Reading file 383 of 636
# Reading file 384 of 636
# Reading file 385 of 636
# Reading file 386 of 636
# Reading file 387 of 636
# Reading file 388 of 636
# Reading file 389 of 636
# Reading file 390 of 636
# Reading file 391 of 636
# Reading file 392 of 636
# Reading file 393 of 636
# Reading file 394 of 636
# Reading file 395 of 636
# Reading file 396 of 636
# Reading file 397 of 636
# Reading file 398 of 636
# Reading file 399 of 636
# Reading file 400 of 636
# Reading file 401 of 636
# Reading file 402 of 636
# Reading file 403 of 636
# Reading file 404 of 636
# Reading file 405 of 636
# Reading file 406 of 636
# Reading file 407 of 636
# Reading file 408 of 636
# Reading file 409 of 636
# Reading file 410 of 636
# Reading file 411 of 636
# Reading file 412 of 636
# Reading file 413 of 636
# Reading file 414 of 636
# Reading file 415 of 636
# Reading file 416 of 636
# Reading file 417 of 636
# Reading file 418 of 636
# Reading file 419 of 636
# Reading file 420 of 636
# Reading file 421 of 636
# Reading file 422 of 636
# Reading file 423 of 636
# Reading file 424 of 636
# Reading file 425 of 636
# Reading file 426 of 636
# Reading file 427 of 636
# Reading file 428 of 636
# Reading file 429 of 636
# Reading file 430 of 636
# Reading file 431 of 636
# Reading file 432 of 636
# Reading file 433 of 636
# Reading file 434 of 636
# Reading file 435 of 636
# Reading file 436 of 636
# Reading file 437 of 636
# Reading file 438 of 636
# Reading file 439 of 636
# Reading file 440 of 636
# Reading file 441 of 636
# Reading file 442 of 636
# Reading file 443 of 636
# Reading file 444 of 636
# Reading file 445 of 636
# Reading file 446 of 636
# Reading file 447 of 636
# Reading file 448 of 636
# Reading file 449 of 636
# Reading file 450 of 636
# Reading file 451 of 636
# Reading file 452 of 636
# Reading file 453 of 636
# Reading file 454 of 636
# Reading file 455 of 636
# Reading file 456 of 636
# Reading file 457 of 636
# Reading file 458 of 636
# Reading file 459 of 636
# Reading file 460 of 636
# Reading file 461 of 636
# Reading file 462 of 636
# Reading file 463 of 636
# Reading file 464 of 636
# Reading file 465 of 636
# Reading file 466 of 636
# Reading file 467 of 636
# Reading file 468 of 636
# Reading file 469 of 636
# Reading file 470 of 636
# Reading file 471 of 636
# Reading file 472 of 636
# Reading file 473 of 636
# Reading file 474 of 636
# Reading file 475 of 636
# Reading file 476 of 636
# Reading file 477 of 636
# Reading file 478 of 636
# Reading file 479 of 636
# Reading file 480 of 636
# Reading file 481 of 636
# Reading file 482 of 636
# Reading file 483 of 636
# Reading file 484 of 636
# Reading file 485 of 636
# Reading file 486 of 636
# Reading file 487 of 636
# Reading file 488 of 636
# Reading file 489 of 636
# Reading file 490 of 636
# Reading file 491 of 636
# Reading file 492 of 636
# Reading file 493 of 636
# Reading file 494 of 636
# Reading file 495 of 636
# Reading file 496 of 636
# Reading file 497 of 636
# Reading file 498 of 636
# Reading file 499 of 636
# Reading file 500 of 636
# Reading file 501 of 636
# Reading file 502 of 636
# Reading file 503 of 636
# Reading file 504 of 636
# Reading file 505 of 636
# Reading file 506 of 636
# Reading file 507 of 636
# Reading file 508 of 636
# Reading file 509 of 636
# Reading file 510 of 636
# Reading file 511 of 636
# Reading file 512 of 636
# Reading file 513 of 636
# Reading file 514 of 636
# Reading file 515 of 636
# Reading file 516 of 636
# Reading file 517 of 636
# Reading file 518 of 636
# Reading file 519 of 636
# Reading file 520 of 636
# Reading file 521 of 636
# Reading file 522 of 636
# Reading file 523 of 636
# Reading file 524 of 636
# Reading file 525 of 636
# Reading file 526 of 636
# Reading file 527 of 636
# Reading file 528 of 636
# Reading file 529 of 636
# Reading file 530 of 636
# Reading file 531 of 636
# Reading file 532 of 636
# Reading file 533 of 636
# Reading file 534 of 636
# Reading file 535 of 636
# Reading file 536 of 636
# Reading file 537 of 636
# Reading file 538 of 636
# Reading file 539 of 636
# Reading file 540 of 636
# Reading file 541 of 636
# Reading file 542 of 636
# Reading file 543 of 636
# Reading file 544 of 636
# Reading file 545 of 636
# Reading file 546 of 636
# Reading file 547 of 636
# Reading file 548 of 636
# Reading file 549 of 636
# Reading file 550 of 636
# Reading file 551 of 636
# Reading file 552 of 636
# Reading file 553 of 636
# Reading file 554 of 636
# Reading file 555 of 636
# Reading file 556 of 636
# Reading file 557 of 636
# Reading file 558 of 636
# Reading file 559 of 636
# Reading file 560 of 636
# Reading file 561 of 636
# Reading file 562 of 636
# Reading file 563 of 636
# Reading file 564 of 636
# Reading file 565 of 636
# Reading file 566 of 636
# Reading file 567 of 636
# Reading file 568 of 636
# Reading file 569 of 636
# Reading file 570 of 636
# Reading file 571 of 636
# Reading file 572 of 636
# Reading file 573 of 636
# Reading file 574 of 636
# Reading file 575 of 636
# Reading file 576 of 636
# Reading file 577 of 636
# Reading file 578 of 636
# Reading file 579 of 636
# Reading file 580 of 636
# Reading file 581 of 636
# Reading file 582 of 636
# Reading file 583 of 636
# Reading file 584 of 636
# Reading file 585 of 636
# Reading file 586 of 636
# Reading file 587 of 636
# Reading file 588 of 636
# Reading file 589 of 636
# Reading file 590 of 636
# Reading file 591 of 636
# Reading file 592 of 636
# Reading file 593 of 636
# Reading file 594 of 636
# Reading file 595 of 636
# Reading file 596 of 636
# Reading file 597 of 636
# Reading file 598 of 636
# Reading file 599 of 636
# Reading file 600 of 636
# Reading file 601 of 636
# Reading file 602 of 636
# Reading file 603 of 636
# Reading file 604 of 636
# Reading file 605 of 636
# Reading file 606 of 636
# Reading file 607 of 636
# Reading file 608 of 636
# Reading file 609 of 636
# Reading file 610 of 636
# Reading file 611 of 636
# Reading file 612 of 636
# Reading file 613 of 636
# Reading file 614 of 636
# Reading file 615 of 636
# Reading file 616 of 636
# Reading file 617 of 636
# Reading file 618 of 636
# Reading file 619 of 636
# Reading file 620 of 636
# Reading file 621 of 636
# Reading file 622 of 636
# Reading file 623 of 636
# Reading file 624 of 636
# Reading file 625 of 636
# Reading file 626 of 636
# Reading file 627 of 636
# Reading file 628 of 636
# Reading file 629 of 636
# Reading file 630 of 636
# Reading file 631 of 636
# Reading file 632 of 636
# Reading file 633 of 636
# Reading file 634 of 636
# Reading file 635 of 636
# Reading file 636 of 636
# Reading file 1 of 636
# Parsing receiver 1 of 1
# Reading file 2 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 3 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 4 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 5 of 636
# Parsing receiver 1 of 12
# Parsing receiver 2 of 12
# Parsing receiver 3 of 12
# Parsing receiver 4 of 12
# Parsing receiver 5 of 12
# Parsing receiver 6 of 12
# Parsing receiver 7 of 12
# Parsing receiver 8 of 12
# Parsing receiver 9 of 12
# Parsing receiver 10 of 12
# Parsing receiver 11 of 12
# Parsing receiver 12 of 12
# Reading file 6 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 7 of 636
# Parsing receiver 1 of 1
# Reading file 8 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 9 of 636
# Parsing receiver 1 of 5
# Parsing receiver 2 of 5
# Parsing receiver 3 of 5
# Parsing receiver 4 of 5
# Parsing receiver 5 of 5
# Reading file 10 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 11 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 12 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 13 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 14 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 15 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 16 of 636
# Parsing receiver 1 of 1
# Reading file 17 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 18 of 636
# Parsing receiver 1 of 5
# Parsing receiver 2 of 5
# Parsing receiver 3 of 5
# Parsing receiver 4 of 5
# Parsing receiver 5 of 5
# Reading file 19 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 20 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 21 of 636
# Parsing receiver 1 of 1
# Reading file 22 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 23 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 24 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 25 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 26 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 27 of 636
# Parsing receiver 1 of 1
# Reading file 28 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 29 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 30 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 31 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 32 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 33 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 34 of 636
# Parsing receiver 1 of 1
# Reading file 35 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 36 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 37 of 636
# Parsing receiver 1 of 12
# Parsing receiver 2 of 12
# Parsing receiver 3 of 12
# Parsing receiver 4 of 12
# Parsing receiver 5 of 12
# Parsing receiver 6 of 12
# Parsing receiver 7 of 12
# Parsing receiver 8 of 12
# Parsing receiver 9 of 12
# Parsing receiver 10 of 12
# Parsing receiver 11 of 12
# Parsing receiver 12 of 12
# Reading file 38 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 39 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 40 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 41 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 42 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 43 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 44 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 45 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 46 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 47 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 48 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 49 of 636
# Parsing receiver 1 of 1
# Reading file 50 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 51 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 52 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 53 of 636
# Parsing receiver 1 of 16
# Parsing receiver 2 of 16
# Parsing receiver 3 of 16
# Parsing receiver 4 of 16
# Parsing receiver 5 of 16
# Parsing receiver 6 of 16
# Parsing receiver 7 of 16
# Parsing receiver 8 of 16
# Parsing receiver 9 of 16
# Parsing receiver 10 of 16
# Parsing receiver 11 of 16
# Parsing receiver 12 of 16
# Parsing receiver 13 of 16
# Parsing receiver 14 of 16
# Parsing receiver 15 of 16
# Parsing receiver 16 of 16
# Reading file 54 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 55 of 636
# Parsing receiver 1 of 1
# Reading file 56 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 57 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 58 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 59 of 636
# Parsing receiver 1 of 14
# Parsing receiver 2 of 14
# Parsing receiver 3 of 14
# Parsing receiver 4 of 14
# Parsing receiver 5 of 14
# Parsing receiver 6 of 14
# Parsing receiver 7 of 14
# Parsing receiver 8 of 14
# Parsing receiver 9 of 14
# Parsing receiver 10 of 14
# Parsing receiver 11 of 14
# Parsing receiver 12 of 14
# Parsing receiver 13 of 14
# Parsing receiver 14 of 14
# Reading file 60 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 61 of 636
# Parsing receiver 1 of 5
# Parsing receiver 2 of 5
# Parsing receiver 3 of 5
# Parsing receiver 4 of 5
# Parsing receiver 5 of 5
# Reading file 62 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 63 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 64 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 65 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 66 of 636
# Parsing receiver 1 of 1
# Reading file 67 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 68 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 69 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 70 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 71 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 72 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 73 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 74 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 75 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 76 of 636
# Parsing receiver 1 of 15
# Parsing receiver 2 of 15
# Parsing receiver 3 of 15
# Parsing receiver 4 of 15
# Parsing receiver 5 of 15
# Parsing receiver 6 of 15
# Parsing receiver 7 of 15
# Parsing receiver 8 of 15
# Parsing receiver 9 of 15
# Parsing receiver 10 of 15
# Parsing receiver 11 of 15
# Parsing receiver 12 of 15
# Parsing receiver 13 of 15
# Parsing receiver 14 of 15
# Parsing receiver 15 of 15
# Reading file 77 of 636
# Parsing receiver 1 of 12
# Parsing receiver 2 of 12
# Parsing receiver 3 of 12
# Parsing receiver 4 of 12
# Parsing receiver 5 of 12
# Parsing receiver 6 of 12
# Parsing receiver 7 of 12
# Parsing receiver 8 of 12
# Parsing receiver 9 of 12
# Parsing receiver 10 of 12
# Parsing receiver 11 of 12
# Parsing receiver 12 of 12
# Reading file 78 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 79 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 80 of 636
# Parsing receiver 1 of 15
# Parsing receiver 2 of 15
# Parsing receiver 3 of 15
# Parsing receiver 4 of 15
# Parsing receiver 5 of 15
# Parsing receiver 6 of 15
# Parsing receiver 7 of 15
# Parsing receiver 8 of 15
# Parsing receiver 9 of 15
# Parsing receiver 10 of 15
# Parsing receiver 11 of 15
# Parsing receiver 12 of 15
# Parsing receiver 13 of 15
# Parsing receiver 14 of 15
# Parsing receiver 15 of 15
# Reading file 81 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 82 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 83 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 84 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 85 of 636
# Parsing receiver 1 of 12
# Parsing receiver 2 of 12
# Parsing receiver 3 of 12
# Parsing receiver 4 of 12
# Parsing receiver 5 of 12
# Parsing receiver 6 of 12
# Parsing receiver 7 of 12
# Parsing receiver 8 of 12
# Parsing receiver 9 of 12
# Parsing receiver 10 of 12
# Parsing receiver 11 of 12
# Parsing receiver 12 of 12
# Reading file 86 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 87 of 636
# Parsing receiver 1 of 1
# Reading file 88 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 89 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 90 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 91 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 92 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 93 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 94 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 95 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 96 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 97 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 98 of 636
# Parsing receiver 1 of 1
# Reading file 99 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 100 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 101 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 102 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 103 of 636
# Parsing receiver 1 of 12
# Parsing receiver 2 of 12
# Parsing receiver 3 of 12
# Parsing receiver 4 of 12
# Parsing receiver 5 of 12
# Parsing receiver 6 of 12
# Parsing receiver 7 of 12
# Parsing receiver 8 of 12
# Parsing receiver 9 of 12
# Parsing receiver 10 of 12
# Parsing receiver 11 of 12
# Parsing receiver 12 of 12
# Reading file 104 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 105 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 106 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 107 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 108 of 636
# Parsing receiver 1 of 1
# Reading file 109 of 636
# Parsing receiver 1 of 5
# Parsing receiver 2 of 5
# Parsing receiver 3 of 5
# Parsing receiver 4 of 5
# Parsing receiver 5 of 5
# Reading file 110 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 111 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 112 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 113 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 114 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 115 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 116 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 117 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 118 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 119 of 636
# Parsing receiver 1 of 5
# Parsing receiver 2 of 5
# Parsing receiver 3 of 5
# Parsing receiver 4 of 5
# Parsing receiver 5 of 5
# Reading file 120 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 121 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 122 of 636
# Parsing receiver 1 of 1
# Reading file 123 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 124 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 125 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 126 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 127 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 128 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 129 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 130 of 636
# Parsing receiver 1 of 12
# Parsing receiver 2 of 12
# Parsing receiver 3 of 12
# Parsing receiver 4 of 12
# Parsing receiver 5 of 12
# Parsing receiver 6 of 12
# Parsing receiver 7 of 12
# Parsing receiver 8 of 12
# Parsing receiver 9 of 12
# Parsing receiver 10 of 12
# Parsing receiver 11 of 12
# Parsing receiver 12 of 12
# Reading file 131 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 132 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 133 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 134 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 135 of 636
# Parsing receiver 1 of 14
# Parsing receiver 2 of 14
# Parsing receiver 3 of 14
# Parsing receiver 4 of 14
# Parsing receiver 5 of 14
# Parsing receiver 6 of 14
# Parsing receiver 7 of 14
# Parsing receiver 8 of 14
# Parsing receiver 9 of 14
# Parsing receiver 10 of 14
# Parsing receiver 11 of 14
# Parsing receiver 12 of 14
# Parsing receiver 13 of 14
# Parsing receiver 14 of 14
# Reading file 136 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 137 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 138 of 636
# Parsing receiver 1 of 17
# Parsing receiver 2 of 17
# Parsing receiver 3 of 17
# Parsing receiver 4 of 17
# Parsing receiver 5 of 17
# Parsing receiver 6 of 17
# Parsing receiver 7 of 17
# Parsing receiver 8 of 17
# Parsing receiver 9 of 17
# Parsing receiver 10 of 17
# Parsing receiver 11 of 17
# Parsing receiver 12 of 17
# Parsing receiver 13 of 17
# Parsing receiver 14 of 17
# Parsing receiver 15 of 17
# Parsing receiver 16 of 17
# Parsing receiver 17 of 17
# Reading file 139 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 140 of 636
# Parsing receiver 1 of 15
# Parsing receiver 2 of 15
# Parsing receiver 3 of 15
# Parsing receiver 4 of 15
# Parsing receiver 5 of 15
# Parsing receiver 6 of 15
# Parsing receiver 7 of 15
# Parsing receiver 8 of 15
# Parsing receiver 9 of 15
# Parsing receiver 10 of 15
# Parsing receiver 11 of 15
# Parsing receiver 12 of 15
# Parsing receiver 13 of 15
# Parsing receiver 14 of 15
# Parsing receiver 15 of 15
# Reading file 141 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 142 of 636
# Parsing receiver 1 of 1
# Reading file 143 of 636
# Parsing receiver 1 of 16
# Parsing receiver 2 of 16
# Parsing receiver 3 of 16
# Parsing receiver 4 of 16
# Parsing receiver 5 of 16
# Parsing receiver 6 of 16
# Parsing receiver 7 of 16
# Parsing receiver 8 of 16
# Parsing receiver 9 of 16
# Parsing receiver 10 of 16
# Parsing receiver 11 of 16
# Parsing receiver 12 of 16
# Parsing receiver 13 of 16
# Parsing receiver 14 of 16
# Parsing receiver 15 of 16
# Parsing receiver 16 of 16
# Reading file 144 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 145 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 146 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 147 of 636
# Parsing receiver 1 of 5
# Parsing receiver 2 of 5
# Parsing receiver 3 of 5
# Parsing receiver 4 of 5
# Parsing receiver 5 of 5
# Reading file 148 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 149 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 150 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 151 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 152 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 153 of 636
# Parsing receiver 1 of 14
# Parsing receiver 2 of 14
# Parsing receiver 3 of 14
# Parsing receiver 4 of 14
# Parsing receiver 5 of 14
# Parsing receiver 6 of 14
# Parsing receiver 7 of 14
# Parsing receiver 8 of 14
# Parsing receiver 9 of 14
# Parsing receiver 10 of 14
# Parsing receiver 11 of 14
# Parsing receiver 12 of 14
# Parsing receiver 13 of 14
# Parsing receiver 14 of 14
# Reading file 154 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 155 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 156 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 157 of 636
# Parsing receiver 1 of 3
# Parsing receiver 2 of 3
# Parsing receiver 3 of 3
# Reading file 158 of 636
# Parsing receiver 1 of 13
# Parsing receiver 2 of 13
# Parsing receiver 3 of 13
# Parsing receiver 4 of 13
# Parsing receiver 5 of 13
# Parsing receiver 6 of 13
# Parsing receiver 7 of 13
# Parsing receiver 8 of 13
# Parsing receiver 9 of 13
# Parsing receiver 10 of 13
# Parsing receiver 11 of 13
# Parsing receiver 12 of 13
# Parsing receiver 13 of 13
# Reading file 159 of 636
# Parsing receiver 1 of 1
# Reading file 160 of 636
# Parsing receiver 1 of 1
# Reading file 161 of 636
# Parsing receiver 1 of 2
# Parsing receiver 2 of 2
# Reading file 162 of 636
# Parsing receiver 1 of 17
# Parsing receiver 2 of 17
# Parsing receiver 3 of 17
# Parsing receiver 4 of 17
# Parsing receiver 5 of 17
# Parsing receiver 6 of 17
# Parsing receiver 7 of 17
# Parsing receiver 8 of 17
# Parsing receiver 9 of 17
# Parsing receiver 10 of 17
# Parsing receiver 11 of 17
# Parsing receiver 12 of 17
# Parsing receiver 13 of 17
# Parsing receiver 14 of 17
# Parsing receiver 15 of 17
# Parsing receiver 16 of 17
# Parsing receiver 17 of 17
# Reading file 163 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 164 of 636
# Parsing receiver 1 of 7
# Parsing receiver 2 of 7
# Parsing receiver 3 of 7
# Parsing receiver 4 of 7
# Parsing receiver 5 of 7
# Parsing receiver 6 of 7
# Parsing receiver 7 of 7
# Reading file 165 of 636
# Parsing receiver 1 of 15
# Parsing receiver 2 of 15
# Parsing receiver 3 of 15
# Parsing receiver 4 of 15
# Parsing receiver 5 of 15
# Parsing receiver 6 of 15
# Parsing receiver 7 of 15
# Parsing receiver 8 of 15
# Parsing receiver 9 of 15
# Parsing receiver 10 of 15
# Parsing receiver 11 of 15
# Parsing receiver 12 of 15
# Parsing receiver 13 of 15
# Parsing receiver 14 of 15
# Parsing receiver 15 of 15
# Reading file 166 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 167 of 636
# Parsing receiver 1 of 6
# Parsing receiver 2 of 6
# Parsing receiver 3 of 6
# Parsing receiver 4 of 6
# Parsing receiver 5 of 6
# Parsing receiver 6 of 6
# Reading file 168 of 636
# Parsing receiver 1 of 10
# Parsing receiver 2 of 10
# Parsing receiver 3 of 10
# Parsing receiver 4 of 10
# Parsing receiver 5 of 10
# Parsing receiver 6 of 10
# Parsing receiver 7 of 10
# Parsing receiver 8 of 10
# Parsing receiver 9 of 10
# Parsing receiver 10 of 10
# Reading file 169 of 636
# Parsing receiver 1 of 8
# Parsing receiver 2 of 8
# Parsing receiver 3 of 8
# Parsing receiver 4 of 8
# Parsing receiver 5 of 8
# Parsing receiver 6 of 8
# Parsing receiver 7 of 8
# Parsing receiver 8 of 8
# Reading file 170 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 171 of 636
# Parsing receiver 1 of 9
# Parsing receiver 2 of 9
# Parsing receiver 3 of 9
# Parsing receiver 4 of 9
# Parsing receiver 5 of 9
# Parsing receiver 6 of 9
# Parsing receiver 7 of 9
# Parsing receiver 8 of 9
# Parsing receiver 9 of 9
# Reading file 172 of 636
# Parsing receiver 1 of 1
# Reading file 173 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# Parsing receiver 3 of 4
# Parsing receiver 4 of 4
# Reading file 174 of 636
# Parsing receiver 1 of 11
# Parsing receiver 2 of 11
# Parsing receiver 3 of 11
# Parsing receiver 4 of 11
# Parsing receiver 5 of 11
# Parsing receiver 6 of 11
# Parsing receiver 7 of 11
# Parsing receiver 8 of 11
# Parsing receiver 9 of 11
# Parsing receiver 10 of 11
# Parsing receiver 11 of 11
# Reading file 175 of 636
# Parsing receiver 1 of 4
# Parsing receiver 2 of 4
# ...
# Parsing receiver 14 of 100
# Parsing receiver 15 of 100
# Parsing receiver 16 of 100
# Parsing receiver 17 of 100
# Parsing receiver 18 of 100
# Parsing receiver 19 of 100
# Parsing receiver 20 of 100
# Parsing receiver 21 of 100
# Parsing receiver 22 of 100
# Parsing receiver 23 of 100
# Parsing receiver 24 of 100
# Parsing receiver 25 of 100
# Parsing receiver 26 of 100
# Parsing receiver 27 of 100
# Parsing receiver 28 of 100
# Parsing receiver 29 of 100
# Parsing receiver 30 of 100
# Parsing receiver 31 of 100
# Parsing receiver 32 of 100
# Parsing receiver 33 of 100
# Parsing receiver 34 of 100
# Parsing receiver 35 of 100
# Parsing receiver 36 of 100
# Parsing receiver 37 of 100
# Parsing receiver 38 of 100
# Parsing receiver 39 of 100
# Parsing receiver 40 of 100
# Parsing receiver 41 of 100
# Parsing receiver 42 of 100
# Parsing receiver 43 of 100
# Parsing receiver 44 of 100
# Parsing receiver 45 of 100
# Parsing receiver 46 of 100
# Parsing receiver 47 of 100
# Parsing receiver 48 of 100
# Parsing receiver 49 of 100
# Parsing receiver 50 of 100
# Parsing receiver 51 of 100
# Parsing receiver 52 of 100
# Parsing receiver 53 of 100
# Parsing receiver 54 of 100
# Parsing receiver 55 of 100
# Parsing receiver 56 of 100
# Parsing receiver 57 of 100
# Parsing receiver 58 of 100
# Parsing receiver 59 of 100
# Parsing receiver 60 of 100
# Parsing receiver 61 of 100
# Parsing receiver 62 of 100
# Parsing receiver 63 of 100
# Parsing receiver 64 of 100
# Parsing receiver 65 of 100
# Parsing receiver 66 of 100
# Parsing receiver 67 of 100
# Parsing receiver 68 of 100
# Parsing receiver 69 of 100
# Parsing receiver 70 of 100
# Parsing receiver 71 of 100
# Parsing receiver 72 of 100
# Parsing receiver 73 of 100
# Parsing receiver 74 of 100
# Parsing receiver 75 of 100
# Parsing receiver 76 of 100
# Parsing receiver 77 of 100
# Parsing receiver 78 of 100
# Parsing receiver 79 of 100
# Parsing receiver 80 of 100
# Parsing receiver 81 of 100
# Parsing receiver 82 of 100
# Parsing receiver 83 of 100
# Parsing receiver 84 of 100
# Parsing receiver 85 of 100
# Parsing receiver 86 of 100
# Parsing receiver 87 of 100
# Parsing receiver 88 of 100
# Parsing receiver 89 of 100
# Parsing receiver 90 of 100
# Parsing receiver 91 of 100
# Parsing receiver 92 of 100
# Parsing receiver 93 of 100
# Parsing receiver 94 of 100
# Parsing receiver 95 of 100
# Parsing receiver 96 of 100
# Parsing receiver 97 of 100
# Parsing receiver 98 of 100
# Parsing receiver 99 of 100
# Parsing receiver 100 of 100
# Reading file 982 of 987
# Parsing receiver 1 of 100
# Parsing receiver 2 of 100
# Parsing receiver 3 of 100
# Parsing receiver 4 of 100
# Parsing receiver 5 of 100
# Parsing receiver 6 of 100
# Parsing receiver 7 of 100
# Parsing receiver 8 of 100
# Parsing receiver 9 of 100
# Parsing receiver 10 of 100
# Parsing receiver 11 of 100
# Parsing receiver 12 of 100
# Parsing receiver 13 of 100
# Parsing receiver 14 of 100
# Parsing receiver 15 of 100
# Parsing receiver 16 of 100
# Parsing receiver 17 of 100
# Parsing receiver 18 of 100
# Parsing receiver 19 of 100
# Parsing receiver 20 of 100
# Parsing receiver 21 of 100
# Parsing receiver 22 of 100
# Parsing receiver 23 of 100
# Parsing receiver 24 of 100
# Parsing receiver 25 of 100
# Parsing receiver 26 of 100
# Parsing receiver 27 of 100
# Parsing receiver 28 of 100
# Parsing receiver 29 of 100
# Parsing receiver 30 of 100
# Parsing receiver 31 of 100
# Parsing receiver 32 of 100
# Parsing receiver 33 of 100
# Parsing receiver 34 of 100
# Parsing receiver 35 of 100
# Parsing receiver 36 of 100
# Parsing receiver 37 of 100
# Parsing receiver 38 of 100
# Parsing receiver 39 of 100
# Parsing receiver 40 of 100
# Parsing receiver 41 of 100
# Parsing receiver 42 of 100
# Parsing receiver 43 of 100
# Parsing receiver 44 of 100
# Parsing receiver 45 of 100
# Parsing receiver 46 of 100
# Parsing receiver 47 of 100
# Parsing receiver 48 of 100
# Parsing receiver 49 of 100
# Parsing receiver 50 of 100
# Parsing receiver 51 of 100
# Parsing receiver 52 of 100
# Parsing receiver 53 of 100
# Parsing receiver 54 of 100
# Parsing receiver 55 of 100
# Parsing receiver 56 of 100
# Parsing receiver 57 of 100
# Parsing receiver 58 of 100
# Parsing receiver 59 of 100
# Parsing receiver 60 of 100
# Parsing receiver 61 of 100
# Parsing receiver 62 of 100
# Parsing receiver 63 of 100
# Parsing receiver 64 of 100
# Parsing receiver 65 of 100
# Parsing receiver 66 of 100
# Parsing receiver 67 of 100
# Parsing receiver 68 of 100
# Parsing receiver 69 of 100
# Parsing receiver 70 of 100
# Parsing receiver 71 of 100
# Parsing receiver 72 of 100
# Parsing receiver 73 of 100
# Parsing receiver 74 of 100
# Parsing receiver 75 of 100
# Parsing receiver 76 of 100
# Parsing receiver 77 of 100
# Parsing receiver 78 of 100
# Parsing receiver 79 of 100
# Parsing receiver 80 of 100
# Parsing receiver 81 of 100
# Parsing receiver 82 of 100
# Parsing receiver 83 of 100
# Parsing receiver 84 of 100
# Parsing receiver 85 of 100
# Parsing receiver 86 of 100
# Parsing receiver 87 of 100
# Parsing receiver 88 of 100
# Parsing receiver 89 of 100
# Parsing receiver 90 of 100
# Parsing receiver 91 of 100
# Parsing receiver 92 of 100
# Parsing receiver 93 of 100
# Parsing receiver 94 of 100
# Parsing receiver 95 of 100
# Parsing receiver 96 of 100
# Parsing receiver 97 of 100
# Parsing receiver 98 of 100
# Parsing receiver 99 of 100
# Parsing receiver 100 of 100
# Reading file 983 of 987
# Parsing receiver 1 of 100
# Parsing receiver 2 of 100
# Parsing receiver 3 of 100
# Parsing receiver 4 of 100
# Parsing receiver 5 of 100
# Parsing receiver 6 of 100
# Parsing receiver 7 of 100
# Parsing receiver 8 of 100
# Parsing receiver 9 of 100
# Parsing receiver 10 of 100
# Parsing receiver 11 of 100
# Parsing receiver 12 of 100
# Parsing receiver 13 of 100
# Parsing receiver 14 of 100
# Parsing receiver 15 of 100
# Parsing receiver 16 of 100
# Parsing receiver 17 of 100
# Parsing receiver 18 of 100
# Parsing receiver 19 of 100
# Parsing receiver 20 of 100
# Parsing receiver 21 of 100
# Parsing receiver 22 of 100
# Parsing receiver 23 of 100
# Parsing receiver 24 of 100
# Parsing receiver 25 of 100
# Parsing receiver 26 of 100
# Parsing receiver 27 of 100
# Parsing receiver 28 of 100
# Parsing receiver 29 of 100
# Parsing receiver 30 of 100
# Parsing receiver 31 of 100
# Parsing receiver 32 of 100
# Parsing receiver 33 of 100
# Parsing receiver 34 of 100
# Parsing receiver 35 of 100
# Parsing receiver 36 of 100
# Parsing receiver 37 of 100
# Parsing receiver 38 of 100
# Parsing receiver 39 of 100
# Parsing receiver 40 of 100
# Parsing receiver 41 of 100
# Parsing receiver 42 of 100
# Parsing receiver 43 of 100
# Parsing receiver 44 of 100
# Parsing receiver 45 of 100
# Parsing receiver 46 of 100
# Parsing receiver 47 of 100
# Parsing receiver 48 of 100
# Parsing receiver 49 of 100
# Parsing receiver 50 of 100
# Parsing receiver 51 of 100
# Parsing receiver 52 of 100
# Parsing receiver 53 of 100
# Parsing receiver 54 of 100
# Parsing receiver 55 of 100
# Parsing receiver 56 of 100
# Parsing receiver 57 of 100
# Parsing receiver 58 of 100
# Parsing receiver 59 of 100
# Parsing receiver 60 of 100
# Parsing receiver 61 of 100
# Parsing receiver 62 of 100
# Parsing receiver 63 of 100
# Parsing receiver 64 of 100
# Parsing receiver 65 of 100
# Parsing receiver 66 of 100
# Parsing receiver 67 of 100
# Parsing receiver 68 of 100
# Parsing receiver 69 of 100
# Parsing receiver 70 of 100
# Parsing receiver 71 of 100
# Parsing receiver 72 of 100
# Parsing receiver 73 of 100
# Parsing receiver 74 of 100
# Parsing receiver 75 of 100
# Parsing receiver 76 of 100
# Parsing receiver 77 of 100
# Parsing receiver 78 of 100
# Parsing receiver 79 of 100
# Parsing receiver 80 of 100
# Parsing receiver 81 of 100
# Parsing receiver 82 of 100
# Parsing receiver 83 of 100
# Parsing receiver 84 of 100
# Parsing receiver 85 of 100
# Parsing receiver 86 of 100
# Parsing receiver 87 of 100
# Parsing receiver 88 of 100
# Parsing receiver 89 of 100
# Parsing receiver 90 of 100
# Parsing receiver 91 of 100
# Parsing receiver 92 of 100
# Parsing receiver 93 of 100
# Parsing receiver 94 of 100
# Parsing receiver 95 of 100
# Parsing receiver 96 of 100
# Parsing receiver 97 of 100
# Parsing receiver 98 of 100
# Parsing receiver 99 of 100
# Parsing receiver 100 of 100
# Reading file 984 of 987
# Parsing receiver 1 of 100
# Parsing receiver 2 of 100
# Parsing receiver 3 of 100
# Parsing receiver 4 of 100
# Parsing receiver 5 of 100
# Parsing receiver 6 of 100
# Parsing receiver 7 of 100
# Parsing receiver 8 of 100
# Parsing receiver 9 of 100
# Parsing receiver 10 of 100
# Parsing receiver 11 of 100
# Parsing receiver 12 of 100
# Parsing receiver 13 of 100
# Parsing receiver 14 of 100
# Parsing receiver 15 of 100
# Parsing receiver 16 of 100
# Parsing receiver 17 of 100
# Parsing receiver 18 of 100
# Parsing receiver 19 of 100
# Parsing receiver 20 of 100
# Parsing receiver 21 of 100
# Parsing receiver 22 of 100
# Parsing receiver 23 of 100
# Parsing receiver 24 of 100
# Parsing receiver 25 of 100
# Parsing receiver 26 of 100
# Parsing receiver 27 of 100
# Parsing receiver 28 of 100
# Parsing receiver 29 of 100
# Parsing receiver 30 of 100
# Parsing receiver 31 of 100
# Parsing receiver 32 of 100
# Parsing receiver 33 of 100
# Parsing receiver 34 of 100
# Parsing receiver 35 of 100
# Parsing receiver 36 of 100
# Parsing receiver 37 of 100
# Parsing receiver 38 of 100
# Parsing receiver 39 of 100
# Parsing receiver 40 of 100
# Parsing receiver 41 of 100
# Parsing receiver 42 of 100
# Parsing receiver 43 of 100
# Parsing receiver 44 of 100
# Parsing receiver 45 of 100
# Parsing receiver 46 of 100
# Parsing receiver 47 of 100
# Parsing receiver 48 of 100
# Parsing receiver 49 of 100
# Parsing receiver 50 of 100
# Parsing receiver 51 of 100
# Parsing receiver 52 of 100
# Parsing receiver 53 of 100
# Parsing receiver 54 of 100
# Parsing receiver 55 of 100
# Parsing receiver 56 of 100
# Parsing receiver 57 of 100
# Parsing receiver 58 of 100
# Parsing receiver 59 of 100
# Parsing receiver 60 of 100
# Parsing receiver 61 of 100
# Parsing receiver 62 of 100
# Parsing receiver 63 of 100
# Parsing receiver 64 of 100
# Parsing receiver 65 of 100
# Parsing receiver 66 of 100
# Parsing receiver 67 of 100
# Parsing receiver 68 of 100
# Parsing receiver 69 of 100
# Parsing receiver 70 of 100
# Parsing receiver 71 of 100
# Parsing receiver 72 of 100
# Parsing receiver 73 of 100
# Parsing receiver 74 of 100
# Parsing receiver 75 of 100
# Parsing receiver 76 of 100
# Parsing receiver 77 of 100
# Parsing receiver 78 of 100
# Parsing receiver 79 of 100
# Parsing receiver 80 of 100
# Parsing receiver 81 of 100
# Parsing receiver 82 of 100
# Parsing receiver 83 of 100
# Parsing receiver 84 of 100
# Parsing receiver 85 of 100
# Parsing receiver 86 of 100
# Parsing receiver 87 of 100
# Parsing receiver 88 of 100
# Parsing receiver 89 of 100
# Parsing receiver 90 of 100
# Parsing receiver 91 of 100
# Parsing receiver 92 of 100
# Parsing receiver 93 of 100
# Parsing receiver 94 of 100
# Parsing receiver 95 of 100
# Parsing receiver 96 of 100
# Parsing receiver 97 of 100
# Parsing receiver 98 of 100
# Parsing receiver 99 of 100
# Parsing receiver 100 of 100
# Reading file 985 of 987
# Parsing receiver 1 of 100
# Parsing receiver 2 of 100
# Parsing receiver 3 of 100
# Parsing receiver 4 of 100
# Parsing receiver 5 of 100
# Parsing receiver 6 of 100
# Parsing receiver 7 of 100
# Parsing receiver 8 of 100
# Parsing receiver 9 of 100
# Parsing receiver 10 of 100
# Parsing receiver 11 of 100
# Parsing receiver 12 of 100
# Parsing receiver 13 of 100
# Parsing receiver 14 of 100
# Parsing receiver 15 of 100
# Parsing receiver 16 of 100
# Parsing receiver 17 of 100
# Parsing receiver 18 of 100
# Parsing receiver 19 of 100
# Parsing receiver 20 of 100
# Parsing receiver 21 of 100
# Parsing receiver 22 of 100
# Parsing receiver 23 of 100
# Parsing receiver 24 of 100
# Parsing receiver 25 of 100
# Parsing receiver 26 of 100
# Parsing receiver 27 of 100
# Parsing receiver 28 of 100
# Parsing receiver 29 of 100
# Parsing receiver 30 of 100
# Parsing receiver 31 of 100
# Parsing receiver 32 of 100
# Parsing receiver 33 of 100
# Parsing receiver 34 of 100
# Parsing receiver 35 of 100
# Parsing receiver 36 of 100
# Parsing receiver 37 of 100
# Parsing receiver 38 of 100
# Parsing receiver 39 of 100
# Parsing receiver 40 of 100
# Parsing receiver 41 of 100
# Parsing receiver 42 of 100
# Parsing receiver 43 of 100
# Parsing receiver 44 of 100
# Parsing receiver 45 of 100
# Parsing receiver 46 of 100
# Parsing receiver 47 of 100
# Parsing receiver 48 of 100
# Parsing receiver 49 of 100
# Parsing receiver 50 of 100
# Parsing receiver 51 of 100
# Parsing receiver 52 of 100
# Parsing receiver 53 of 100
# Parsing receiver 54 of 100
# Parsing receiver 55 of 100
# Parsing receiver 56 of 100
# Parsing receiver 57 of 100
# Parsing receiver 58 of 100
# Parsing receiver 59 of 100
# Parsing receiver 60 of 100
# Parsing receiver 61 of 100
# Parsing receiver 62 of 100
# Parsing receiver 63 of 100
# Parsing receiver 64 of 100
# Parsing receiver 65 of 100
# Parsing receiver 66 of 100
# Parsing receiver 67 of 100
# Parsing receiver 68 of 100
# Parsing receiver 69 of 100
# Parsing receiver 70 of 100
# Parsing receiver 71 of 100
# Parsing receiver 72 of 100
# Parsing receiver 73 of 100
# Parsing receiver 74 of 100
# Parsing receiver 75 of 100
# Parsing receiver 76 of 100
# Parsing receiver 77 of 100
# Parsing receiver 78 of 100
# Parsing receiver 79 of 100
# Parsing receiver 80 of 100
# Parsing receiver 81 of 100
# Parsing receiver 82 of 100
# Parsing receiver 83 of 100
# Parsing receiver 84 of 100
# Parsing receiver 85 of 100
# Parsing receiver 86 of 100
# Parsing receiver 87 of 100
# Parsing receiver 88 of 100
# Parsing receiver 89 of 100
# Parsing receiver 90 of 100
# Parsing receiver 91 of 100
# Parsing receiver 92 of 100
# Parsing receiver 93 of 100
# Parsing receiver 94 of 100
# Parsing receiver 95 of 100
# Parsing receiver 96 of 100
# Parsing receiver 97 of 100
# Parsing receiver 98 of 100
# Parsing receiver 99 of 100
# Parsing receiver 100 of 100
# Reading file 986 of 987
# Parsing receiver 1 of 100
# Parsing receiver 2 of 100
# Parsing receiver 3 of 100
# Parsing receiver 4 of 100
# Parsing receiver 5 of 100
# Parsing receiver 6 of 100
# Parsing receiver 7 of 100
# Parsing receiver 8 of 100
# Parsing receiver 9 of 100
# Parsing receiver 10 of 100
# Parsing receiver 11 of 100
# Parsing receiver 12 of 100
# Parsing receiver 13 of 100
# Parsing receiver 14 of 100
# Parsing receiver 15 of 100
# Parsing receiver 16 of 100
# Parsing receiver 17 of 100
# Parsing receiver 18 of 100
# Parsing receiver 19 of 100
# Parsing receiver 20 of 100
# Parsing receiver 21 of 100
# Parsing receiver 22 of 100
# Parsing receiver 23 of 100
# Parsing receiver 24 of 100
# Parsing receiver 25 of 100
# Parsing receiver 26 of 100
# Parsing receiver 27 of 100
# Parsing receiver 28 of 100
# Parsing receiver 29 of 100
# Parsing receiver 30 of 100
# Parsing receiver 31 of 100
# Parsing receiver 32 of 100
# Parsing receiver 33 of 100
# Parsing receiver 34 of 100
# Parsing receiver 35 of 100
# Parsing receiver 36 of 100
# Parsing receiver 37 of 100
# Parsing receiver 38 of 100
# Parsing receiver 39 of 100
# Parsing receiver 40 of 100
# Parsing receiver 41 of 100
# Parsing receiver 42 of 100
# Parsing receiver 43 of 100
# Parsing receiver 44 of 100
# Parsing receiver 45 of 100
# Parsing receiver 46 of 100
# Parsing receiver 47 of 100
# Parsing receiver 48 of 100
# Parsing receiver 49 of 100
# Parsing receiver 50 of 100
# Parsing receiver 51 of 100
# Parsing receiver 52 of 100
# Parsing receiver 53 of 100
# Parsing receiver 54 of 100
# Parsing receiver 55 of 100
# Parsing receiver 56 of 100
# Parsing receiver 57 of 100
# Parsing receiver 58 of 100
# Parsing receiver 59 of 100
# Parsing receiver 60 of 100
# Parsing receiver 61 of 100
# Parsing receiver 62 of 100
# Parsing receiver 63 of 100
# Parsing receiver 64 of 100
# Parsing receiver 65 of 100
# Parsing receiver 66 of 100
# Parsing receiver 67 of 100
# Parsing receiver 68 of 100
# Parsing receiver 69 of 100
# Parsing receiver 70 of 100
# Parsing receiver 71 of 100
# Parsing receiver 72 of 100
# Parsing receiver 73 of 100
# Parsing receiver 74 of 100
# Parsing receiver 75 of 100
# Parsing receiver 76 of 100
# Parsing receiver 77 of 100
# Parsing receiver 78 of 100
# Parsing receiver 79 of 100
# Parsing receiver 80 of 100
# Parsing receiver 81 of 100
# Parsing receiver 82 of 100
# Parsing receiver 83 of 100
# Parsing receiver 84 of 100
# Parsing receiver 85 of 100
# Parsing receiver 86 of 100
# Parsing receiver 87 of 100
# Parsing receiver 88 of 100
# Parsing receiver 89 of 100
# Parsing receiver 90 of 100
# Parsing receiver 91 of 100
# Parsing receiver 92 of 100
# Parsing receiver 93 of 100
# Parsing receiver 94 of 100
# Parsing receiver 95 of 100
# Parsing receiver 96 of 100
# Parsing receiver 97 of 100
# Parsing receiver 98 of 100
# Parsing receiver 99 of 100
# Parsing receiver 100 of 100
# Reading file 987 of 987
# Parsing receiver 1 of 1

# %%
# Match with exact matching key [This should line up perfectly because we simply copy the same file from one folder to the next; they should be identical]
raw_receivers_df['match_key'] = raw_receivers_df.apply(lambda x: get_match_key(x, exact_match=True), axis=1)
processed_receivers_df['match_key'] = processed_receivers_df.apply(lambda x: get_match_key(x, exact_match=True), axis=1)
raw_files_to_processed_files_missing_keys = [key for key in raw_receivers_df.match_key.tolist() if key not in processed_receivers_df.match_key.tolist()]

# %% [markdown]
# ## Audit received receivers and receivers in DB

# %%
# Get receivers from DB. This would be all the invoices from Tony's export location (group 56351)
receivers_query = f"""
SELECT ii.invoice_number as invoice_number, ii.date as date, ii.total_amount as total_amount, split_part(ii.batch_number, '|', 1) as filename,
    rvad.vendor_name as vendor_id, ra.company_code as location_id
FROM invoices_invoice ii
JOIN restaurant_restaurant rr on ii.restaurant_id = rr.id
JOIN accounting_restaurantvendoraccountdetails rvad on rvad.id = ii.rvad_id
JOIN accounting_restaurantaccount ra on ra.restaurant_id = ii.restaurant_id
WHERE rr.group_id = 56351
    AND ii.date >= '{FROM_DATE}'
;
"""

db_receivers_df = pd.read_sql(receivers_query, engine)
db_receivers_df.drop_duplicates(subset=['invoice_number', 'date', 'total_amount', 'vendor_id', 'location_id'], keep='first', inplace=True)
engine.dispose()

# %%
# Do the same receiver parity checks but between raw and db receivers
raw_receivers_df['match_key'] = raw_receivers_df.apply(lambda x: get_match_key(x, exact_match=True), axis=1)
db_receivers_df['match_key'] = db_receivers_df.apply(lambda x: get_match_key(x, exact_match=True), axis=1)
# display(raw_receivers_df.head())
# display(db_receivers_df.head())

raw_to_db_missing_keys = [key for key in raw_receivers_df.match_key.tolist() if key not in db_receivers_df.match_key.tolist()]

# %% [markdown]
# # Check Dangling Images for matching Receivers

# %%
# Dangling images query
danling_images_query = """
SELECT ii.id, ii.invoice_number, ii.total_amount, ii.is_flagged, ii.date AS date,
    rvad.vendor_name AS vendor_id, ra.company_code AS location_id
FROM invoices_invoice  ii
JOIN restaurant_restaurant rr ON ii.restaurant_id = rr.id
JOIN accounting_restaurantvendoraccountdetails rvad ON rvad.id = ii.rvad_id
JOIN accounting_restaurantaccount ra ON ra.restaurant_id = ii.restaurant_id
WHERE 1=1
    AND rr.group_id = 56350
    AND ii.state IN (2, -2)
    AND ii.approved_date IS NULL
    AND ii.exported_date IS NULL
    AND ii.invoice_number IS NOT NULL;
"""

dangling_images_df = pd.read_sql(danling_images_query, engine)
engine.dispose()

# %%
# Do exact matches for dangling receivers from raw receivers files
left = dangling_images_df.copy()
left['date'] = pd.to_datetime(left['date'])

right = raw_receivers_df.copy()

left['match_key'] = left.apply(lambda x: get_match_key(x, exact_match=True), axis=1)
right['match_key'] = right.apply(lambda x: get_match_key(x, exact_match=True), axis=1)

exact_image_matches = right.merge(left, on='match_key', suffixes=('_image', '_right'))

if not exact_image_matches.empty:
    print(f'Found these matches:')
    display(exact_image_matches)

# %%
# Do fuzzy matches for dangling receivers from raw receivers files

remaining_images = left[~left.match_key.isin(exact_image_matches.match_key.tolist())]

if not remaining_images.empty:
    print(f'Trying to find fuzzy matches for remaining {len(remaining_images)} images:')

    left['match_key'] = left.apply(lambda x: get_match_key(x, exact_match=False), axis=1)
    right['match_key'] = right.apply(lambda x: get_match_key(x, exact_match=False), axis=1)

    fuzzy_image_matches = right.merge(left, on='match_key', suffixes=('_image', '_right'))

    if not fuzzy_image_matches.empty:
        print('Found these fuzzy matches:')
        display(fuzzy_image_matches)

    remaining_images = remaining_images[~remaining_images.match_key.isin(fuzzy_image_matches.match_key.tolist())]

    if not remaining_images.empty:
        print('Trying to do some more matches using vendor, amount, location, and date')
        alternate_attempt_df = remaining_images.merge(left, on=['vendor_id', 'location_id', 'total_amount', 'date'], suffixes=('_image', '_raw'))

        if not alternate_attempt_df.empty:
            print('Found these matches using vendor, amount, location, and date')
            display(alternate_attempt_df)

        remaining_images = remaining_images[~remaining_images.match_key.isin(alternate_attempt_df.match_key_image.tolist())]

        if not remaining_images.empty:
            print('Trying to do some more matches using amount, location, and date')
            final_attempt_df = remaining_images.merge(left, on=['location_id', 'total_amount', 'date'], suffixes=('_image', '_raw'))

            if not final_attempt_df.empty:
                print('Found these matches using amount, location, and date')
                display(final_attempt_df)

            remaining_images = remaining_images[~remaining_images.match_key.isin(final_attempt_df.match_key_image.tolist())]

            if remaining_images.empty:
                print('No more images left to check for')
            else:
                print('Could not match these remaining images:')
                display(remaining_images)
        else:
            print('No more images remaining to match')

    else:
        print('None Remaining')
# Out:
# Trying to find fuzzy matches for remaining 4 images:
# Trying to do some more matches using vendor, amount, location, and date
# Found these matches using vendor, amount, location, and date
#    id_image invoice_number_image  total_amount  is_flagged_image       date  \
# 0  88507856       52249490004840        149.40             False 2024-04-26
# 1  88515295            CM1848845       -192.00             False 2024-04-26
# 2  88538600               584640         54.00             False 2024-04-28
# 3  88516810              1787582       2646.15             False 2024-04-24
#
#   vendor_id location_id               match_key_image    id_raw  \
# 0    BIMDSD        2012  2012__BIMDSD__52249490004840  88507856
# 1   DUTCH06        2011      2011__DUTCH06__CM1848845  88515295
# 2   TORTI00        2002         2002__TORTI00__584640  88538600
# 3   AMIGO06        2002        2002__AMIGO06__1787582  88516810
#
#   invoice_number_raw  is_flagged_raw                 match_key_raw
# 0     52249490004840           False  2012__BIMDSD__52249490004840
# 1          CM1848845           False        2011__DUTCH06__1848845
# 2             584640           False         2002__TORTI00__584640
# 3            1787582           False        2002__AMIGO06__1787582
# No more images remaining to match

# %% [markdown]
# ## Reporting
# ### No. of Received & Processed Files

# %%
raw_files_data[raw_files_data.date=='2024-04-18']
# Out:
#                                    filename        date
# 204               02006_20240418150007.json  2024-04-18
# 252               02009_20240418150008.json  2024-04-18
# 302               02011_20240418150008.json  2024-04-18
# 351               02012_20240418150009.json  2024-04-18
# 419               02014_20240418150009.json  2024-04-18
# 607  DSD_20240417170504_ap001724190000.json  2024-04-18
# 611  DSD_20240418173504_ap301824193001.json  2024-04-18

# %%
# display(raw_to_processed_files_comparison_df)
print('Raw files to processed files comparison by date:')
display(raw_to_processed_files_comparison_df)


if missing_in_processed_list:
    print("Files in raw missing in processed folder:")
    display(raw_files_data[raw_files_data.filename.isin(missing_in_processed_list)])

    print("Receivers in the missed file(s):")
    raw_receivers_df['cleaned_name'] = raw_receivers_df.apply(lambda x: get_original_filename(x.filename), axis=1)
    display(raw_receivers_df[raw_receivers_df.cleaned_name.isin(missing_in_processed_list)])

else:
    display(HTML('<h3>All files in raw_files folder were found in processed folder</h3>'))
# Out:
# Raw files to processed files comparison by date:
#           date  filename_raw  filename_processed  mismatch
# 0   2024-02-28             3                   3         0
# 1   2024-02-29            15                  15         0
# 2   2024-03-01            16                  16         0
# 3   2024-03-02            13                  13         0
# 4   2024-03-03             4                   4         0
# 5   2024-03-04            14                  14         0
# 6   2024-03-05            15                  15         0
# 7   2024-03-06            16                  16         0
# 8   2024-03-07            15                  15         0
# 9   2024-03-08            15                  15         0
# 10  2024-03-09            12                  12         0
# 11  2024-03-10             5                   5         0
# 12  2024-03-11            15                  15         0
# 13  2024-03-12            15                  15         0
# 14  2024-03-14            13                  29       -16
# 15  2024-03-15            14                  14         0
# 16  2024-03-16             9                   9         0
# 17  2024-03-17             3                   3         0
# 18  2024-03-18            14                  14         0
# 19  2024-03-19            15                  15         0
# 20  2024-03-20            15                  15         0
# 21  2024-03-21            13                  13         0
# 22  2024-03-22            13                  13         0
# 23  2024-03-23             8                   8         0
# 24  2024-03-24             3                   3         0
# 25  2024-03-25            13                  13         0
# 26  2024-03-26            13                  13         0
# 27  2024-03-27            12                  12         0
# 28  2024-03-28            12                  12         0
# 29  2024-03-29            12                  12         0
# 30  2024-03-30            10                  10         0
# 31  2024-03-31             3                   3         0
# 32  2024-04-01            16                  16         0
# 33  2024-04-02            16                  16         0
# 34  2024-04-03            13                  13         0
# 35  2024-04-04            10                  10         0
# 36  2024-04-05            11                  11         0
# 37  2024-04-06             8                   8         0
# 38  2024-04-07             4                   4         0
# 39  2024-04-08            11                  11         0
# 40  2024-04-09            11                  11         0
# 41  2024-04-10            12                  12         0
# 42  2024-04-11             8                   8         0
# 43  2024-04-12            10                  10         0
# 44  2024-04-13             9                   9         0
# 45  2024-04-14             3                   3         0
# 46  2024-04-15            10                  10         0
# 47  2024-04-16            10                  10         0
# 48  2024-04-17            10                  11        -1
# 49  2024-04-18             7                   6         1
# 50  2024-04-19             9                   9         0
# 51  2024-04-20             7                   7         0
# 52  2024-04-21             3                   3         0
# 53  2024-04-22             9                   9         0
# 54  2024-04-23             8                   8         0
# 55  2024-04-24            10                  10         0
# 56  2024-04-25             7                   7         0
# 57  2024-04-26            12                  12         0
# 58  2024-04-27             7                   7         0
# <h3>All files in raw_files folder were found in processed folder</h3>

# %%
# Receivers in raw files VS receivers in processed folder
if raw_files_to_processed_files_missing_keys:
    print('Following receivers were not found in processed folder:')
    raw_to_processed_missing_df = raw_receivers_df[raw_receivers_df.match_key.isin(raw_files_to_processed_files_missing_keys)]
    display(raw_to_processed_missing_df)

    print('Checking partial match in case processed folder invoice numbers have been altered...')
    raw_to_processed_missing_df['match_key'] = raw_to_processed_missing_df.apply(lambda x: get_match_key(row=x, exact_match=False), axis=1)
    processed_receivers_df['match_key'] = processed_receivers_df.apply(lambda x: get_match_key(row=x, exact_match=False), axis=1)

    # Check if any missing now
    fuzzy_missing_raw_keys = [key for key in raw_to_processed_missing_df.match_key.tolist() if key not in processed_receivers_df.match_key.tolist()]

    if fuzzy_missing_raw_keys:
        print('Following receivers are missing in processed even after fuzzy checks:')
        display(raw_receivers_df[raw_receivers_df.match_key.isin(fuzzy_missing_raw_keys)])

    else:
        print('All receivers in raw files were found in processed after trying fuzzy matching')

else:
    print('All receivers in raw files were found in processed folder files')
# Out:
# All receivers in raw files were found in processed folder files

# %% [markdown]
# ### No. of receivers in raw_files folder and Export Location DB

# %%
# match the keys in raw files receivers list with that from the DB

if raw_to_db_missing_keys:
    print('Following receivers were not found in the DB using exact match:')
    raw_to_db_missing_df = raw_receivers_df[raw_receivers_df.match_key.isin(raw_to_db_missing_keys)]
    display(raw_to_db_missing_df)

    print('Trying to match with fuzzy invoice number matching...')
    raw_to_db_missing_df['match_key'] = raw_to_db_missing_df.apply(lambda x: get_match_key(row=x, exact_match=False), axis=1)
    db_receivers_df['match_key'] = db_receivers_df.apply(lambda x: get_match_key(row=x, exact_match=False), axis=1)

    # Check if any missing now
    fuzzy_missing_raw_keys = [key for key in raw_to_db_missing_df.match_key.tolist() if key not in db_receivers_df.match_key.tolist()]
    if fuzzy_missing_raw_keys:
        # This means we couldn't match with the exact check and fuzzy checks. We can only try a couple of different combo-checks to see if anything closely matches
        print('Following receivers were not found in DB even after fuzzy invoice name matching:')
        display(raw_to_db_missing_df[raw_to_db_missing_df.match_key.isin(fuzzy_missing_raw_keys)])

        # Now, do an alternate matching on amount, vendor, date, location to see how much diff is there in the invoice number
        left = raw_receivers_df[raw_receivers_df.match_key.isin(fuzzy_missing_raw_keys)][['vendor_id', 'location_id', 'total_amount', 'date', 'invoice_number', 'match_key']]
        right = db_receivers_df[['vendor_id', 'location_id', 'total_amount', 'date', 'invoice_number', 'match_key']]
        right['date'] = pd.to_datetime(right.date, errors='coerce')
        merged = left.merge(right, on=['vendor_id', 'location_id', 'total_amount', 'date'], suffixes=('_raw', '_db'))

        merged['same_inv_num?'] = merged.invoice_number_db == merged.invoice_number_raw
        if not merged.empty:
            print('Found some following possible matches:')
            display(merged)

        # Check if any more unmatched
        not_in_merged = left[~left.match_key.isin(merged.match_key_raw)]
        if not not_in_merged.empty:
            print('The following receivers were still not found:')
            display(not_in_merged)

            print('Trying one more possible matching using only dates, amounts, and locations...')
            another_merge = not_in_merged.merge(right, on=['total_amount', 'date', 'location_id'], suffixes=('_raw', '_db'))
            another_merge['same_inv_no?'] = another_merge.invoice_number_raw == another_merge.invoice_number_db

            if not another_merge.empty:
                print(f'Following receivers seem like they found a matching invoice:')
                display(another_merge)
            else:
                print('That did not match any receivers')

            still_missing = not_in_merged[~not_in_merged.match_key.isin(another_merge.match_key_raw)]

            if not still_missing.empty:
                print(f'The following receivers did not find a match anywhere in the DB')
                display(still_missing)

            else:
                print('No more missing receivers to check for')
        else:
            print('No more missing receivers to check for')
    else:
        print(f'All receivers in raw were found in DB after trying fuzzy invoice name matching. Trying another match using only amounts, vendors, dates, and locations.')


    # print(fuzzy_missing_raw_keys)
else:
    print('All receivers in raw were found in the DB')
# Out:
# Following receivers were not found in the DB using exact match:
#       invoice_number location_id vendor_id  total_amount       date  \
# 58         NS5364701        2001   DUTCH06         29.94 2024-03-12
# 66              9155        2001   CUGIN09        230.14 2024-03-13
# 227            16190        2001   COUNT00        702.37 2024-04-17
# 265             3489        2001   MBFOO04        187.14 2024-04-24
# 351          4740592        2002   JRDAI00        221.58 2024-03-13
# ...              ...         ...       ...           ...        ...
# 40362    08224201325        2001   HERIT01        478.48 2024-04-26
# 40401       16802216        2012   TURAN00         30.36 2024-04-26
# 40402       16802217        2012   TURAN00         58.10 2024-04-26
# 40490        4050469        2001   CAMER15        649.12 2024-04-26
# 40642        2544913        2006    GOYAFO       1072.96 2024-04-27
#
#                                             filename  \
# 58                  02001_20240312150008__11068.json
# 66                  02001_20240313150008__82977.json
# 227                 02001_20240417150006__32673.json
# 265                 02001_20240424150007__28115.json
# 351                 02002_20240313150008__88558.json
# ...                                              ...
# 40362  DSD_20240426170505_ap002624190000__92916.json
# 40401  DSD_20240426170505_ap002624190000__92916.json
# 40402  DSD_20240426170505_ap002624190000__92916.json
# 40490  DSD_20240426170505_ap002624190000__92916.json
# 40642  DSD_20240427170507_ap002724190000__87387.json
#
#                         match_key
# 58       2001__DUTCH06__NS5364701
# 66            2001__CUGIN09__9155
# 227          2001__COUNT00__16190
# 265           2001__MBFOO04__3489
# 351        2002__JRDAI00__4740592
# ...                           ...
# 40362  2001__HERIT01__08224201325
# 40401     2012__TURAN00__16802216
# 40402     2012__TURAN00__16802217
# 40490      2001__CAMER15__4050469
# 40642       2006__GOYAFO__2544913
#
# [2703 rows x 7 columns]
# Trying to match with fuzzy invoice number matching...
# Following receivers were not found in DB even after fuzzy invoice name matching:
#       invoice_number location_id vendor_id  total_amount       date  \
# 66              9155        2001   CUGIN09        230.14 2024-03-13
# 227            16190        2001   COUNT00        702.37 2024-04-17
# 265             3489        2001   MBFOO04        187.14 2024-04-24
# 351          4740592        2002   JRDAI00        221.58 2024-03-13
# 370        07-071686        2002   LAGUA00         30.96 2024-03-19
# ...              ...         ...       ...           ...        ...
# 40362    08224201325        2001   HERIT01        478.48 2024-04-26
# 40401       16802216        2012   TURAN00         30.36 2024-04-26
# 40402       16802217        2012   TURAN00         58.10 2024-04-26
# 40490        4050469        2001   CAMER15        649.12 2024-04-26
# 40642        2544913        2006    GOYAFO       1072.96 2024-04-27
#
#                                             filename  \
# 66                  02001_20240313150008__82977.json
# 227                 02001_20240417150006__32673.json
# 265                 02001_20240424150007__28115.json
# 351                 02002_20240313150008__88558.json
# 370                 02002_20240319150009__53830.json
# ...                                              ...
# 40362  DSD_20240426170505_ap002624190000__92916.json
# 40401  DSD_20240426170505_ap002624190000__92916.json
# 40402  DSD_20240426170505_ap002624190000__92916.json
# 40490  DSD_20240426170505_ap002624190000__92916.json
# 40642  DSD_20240427170507_ap002724190000__87387.json
#
#                         match_key
# 66            2001__CUGIN09__9155
# 227          2001__COUNT00__16190
# 265           2001__MBFOO04__3489
# 351        2002__JRDAI00__4740592
# 370       2002__LAGUA00__07071686
# ...                           ...
# 40362  2001__HERIT01__08224201325
# 40401     2012__TURAN00__16802216
# 40402     2012__TURAN00__16802217
# 40490      2001__CAMER15__4050469
# 40642       2006__GOYAFO__2544913
#
# [2678 rows x 7 columns]
# Found some following possible matches:
#    vendor_id location_id  total_amount       date invoice_number_raw  \
# 0    CUGIN09        2001        230.14 2024-03-13               9155
# 1    JRDAI00        2002        221.58 2024-03-13            4740592
# 2    LAGUA00        2002         30.96 2024-03-19          07-071686
# 3     BARSFO        2002        761.55 2024-03-23         0782408308
# 4    LIPAR09        2002        127.78 2024-04-02             107337
# ..       ...         ...           ...        ...                ...
# 56   ATOMB00        2002        240.00 2024-04-24          767042424
# 57   HERIT01        2001        478.48 2024-04-26        08224201325
# 58   TURAN00        2012         30.36 2024-04-26           16802216
# 59   TURAN00        2012         58.10 2024-04-26           16802217
# 60   CAMER15        2001        649.12 2024-04-26            4050469
#
#                  match_key_raw invoice_number_db              match_key_db  \
# 0          2001__CUGIN09__9155             99155      2001__CUGIN09__99155
# 1       2002__JRDAI00__4740592          47410592   2002__JRDAI00__47410592
# 2      2002__LAGUA00__07071686         07-021686   2002__LAGUA00__07021686
# 3     2002__BARSFO__0782408308        0782408309  2002__BARSFO__0782408309
# 4        2002__LIPAR09__107337           1017337    2002__LIPAR09__1017337
# ..                         ...               ...                       ...
# 56    2002__ATOMB00__767042424          01109213   2002__ATOMB00__01109213
# 57  2001__HERIT01__08224201325           2678488    2001__HERIT01__2678488
# 58     2012__TURAN00__16802216         168022196  2012__TURAN00__168022196
# 59     2012__TURAN00__16802217         168022197  2012__TURAN00__168022197
# 60      2001__CAMER15__4050469           4500469    2001__CAMER15__4500469
#
#     same_inv_num?
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 56          False
# 57          False
# 58          False
# 59          False
# 60          False
#
# [61 rows x 9 columns]
# The following receivers were still not found:
#       vendor_id location_id  total_amount       date invoice_number  \
# 227     COUNT00        2001        702.37 2024-04-17          16190
# 265     MBFOO04        2001        187.14 2024-04-24           3489
# 1177     BARSFO        2006        528.47 2024-03-15      732407501
# 1350    LIPAR09        2006         46.48 2024-04-16        1072316
# 3533     GOYAFO        2017       2686.00 2024-02-28       25289998
# ...         ...         ...           ...        ...            ...
# 40288    GOYAFO        2011        271.59 2024-04-26       25450560
# 40289    GOYAFO        2011         56.22 2024-04-26       25450561
# 40290    GOYAFO        2002        806.81 2024-04-26       25451012
# 40291    GOYAFO        2002        104.38 2024-04-26       25451013
# 40642    GOYAFO        2006       1072.96 2024-04-27        2544913
#
#                      match_key
# 227       2001__COUNT00__16190
# 265        2001__MBFOO04__3489
# 1177   2006__BARSFO__732407501
# 1350    2006__LIPAR09__1072316
# 3533    2017__GOYAFO__25289998
# ...                        ...
# 40288   2011__GOYAFO__25450560
# 40289   2011__GOYAFO__25450561
# 40290   2002__GOYAFO__25451012
# 40291   2002__GOYAFO__25451013
# 40642    2006__GOYAFO__2544913
#
# [2590 rows x 6 columns]
# Trying one more possible matching using only dates, amounts, and locations...
# Following receivers seem like they found a matching invoice:
#     vendor_id_raw location_id  total_amount       date invoice_number_raw  \
# 0          GOYAFO        2017       2686.00 2024-02-28           25289998
# 1          GOYAFO        2008       3288.57 2024-02-28           25294505
# 2          GOYAFO        2008         56.22 2024-02-28           25294506
# 3          GOYAFO        2013       2129.85 2024-02-28           25294516
# 4          GOYAFO        2006       1144.25 2024-02-29           25298431
# ..            ...         ...           ...        ...                ...
# 121        GOYAFO        2002       1270.76 2024-04-23           25439101
# 122        GOYAFO        2009        318.00 2024-04-25           25446964
# 123        GOYAFO        2011        271.59 2024-04-26           25450560
# 124        GOYAFO        2002        104.38 2024-04-26           25451013
# 125        GOYAFO        2006       1072.96 2024-04-27            2544913
#
#               match_key_raw vendor_id_db invoice_number_db  \
# 0    2017__GOYAFO__25289998      GOYAF00          25289998
# 1    2008__GOYAFO__25294505      GOYAF00          25294505
# 2    2008__GOYAFO__25294506      GOYAF00          25294506
# 3    2013__GOYAFO__25294516      GOYAF00          25294516
# 4    2006__GOYAFO__25298431      GOYAF00          25298431
# ..                      ...          ...               ...
# 121  2002__GOYAFO__25439101      GOYAF00          25439101
# 122  2009__GOYAFO__25446964      GOYAF00          25446964
# 123  2011__GOYAFO__25450560      GOYAF00          25450560
# 124  2002__GOYAFO__25451013      GOYAF00          25451013
# 125   2006__GOYAFO__2544913      GOYAF00           2544913
#
#                 match_key_db  same_inv_no?
# 0    2017__GOYAF00__25289998          True
# 1    2008__GOYAF00__25294505          True
# 2    2008__GOYAF00__25294506          True
# 3    2013__GOYAF00__25294516          True
# 4    2006__GOYAF00__25298431          True
# ..                       ...           ...
# 121  2002__GOYAF00__25439101          True
# 122  2009__GOYAF00__25446964          True
# 123  2011__GOYAF00__25450560          True
# 124  2002__GOYAF00__25451013          True
# 125   2006__GOYAF00__2544913          True
#
# [126 rows x 10 columns]
# The following receivers did not find a match anywhere in the DB
#       vendor_id location_id  total_amount       date invoice_number  \
# 227     COUNT00        2001        702.37 2024-04-17          16190
# 265     MBFOO04        2001        187.14 2024-04-24           3489
# 1177     BARSFO        2006        528.47 2024-03-15      732407501
# 1350    LIPAR09        2006         46.48 2024-04-16        1072316
# 3537     GOYAFO        2013         50.70 2024-02-28       25294517
# ...         ...         ...           ...        ...            ...
# 38765    GOYAFO        2001        924.06 2024-04-23       25439528
# 38766    GOYAFO        2011       1076.85 2024-04-23       25439716
# 40287    GOYAFO        2001        896.73 2024-04-26       25449187
# 40289    GOYAFO        2011         56.22 2024-04-26       25450561
# 40290    GOYAFO        2002        806.81 2024-04-26       25451012
#
#                      match_key
# 227       2001__COUNT00__16190
# 265        2001__MBFOO04__3489
# 1177   2006__BARSFO__732407501
# 1350    2006__LIPAR09__1072316
# 3537    2013__GOYAFO__25294517
# ...                        ...
# 38765   2001__GOYAFO__25439528
# 38766   2011__GOYAFO__25439716
# 40287   2001__GOYAFO__25449187
# 40289   2011__GOYAFO__25450561
# 40290   2002__GOYAFO__25451012
#
# [2464 rows x 6 columns]

# %% [markdown]
# ### Check how many SBT Vendors

# %%
sbt_vendor_receivers_df = still_missing[still_missing.vendor_id.isin(sbt_vendors.VEND.tolist())]
if sbt_vendor_receivers_df.empty:
    print('No SBT vendor receivers')
else:
    print('Found the following SBT vendor receivers:')
    display(sbt_vendor_receivers_df)
# Out:
# No SBT vendor receivers

# %% [markdown]
# ## Check for dangling invoice matches in the receivers
